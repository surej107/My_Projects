# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import sqlite3


db_name = 'redbus_data.db'

def insert_into_table(bus_data,cursor,conn):
    sql = """
    INSERT INTO Bus_Routes (route_name, route_link, bus_name, bus_type, departure_time, duration, arrival_time, rating, price, availability)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """
    values = (
        bus_data['route_name'], bus_data['route_link'], bus_data['bus_name'], bus_data['bus_type'],
        bus_data['departure_time'], bus_data['duration'], bus_data['arrival_time'],
        bus_data['rating'], bus_data['price'], bus_data['availability']
    )
    cursor.execute(sql, values)
    conn.commit()


def get_bus_links(driver, urls):
    bus_link = []
    for url in urls:
        driver.get(url)
        time.sleep(1)
        page_tabs = driver.find_elements(By.CLASS_NAME, 'DC_117_pageTabs')
        # print(page_tabs)
        links = 0
        for page_tab in page_tabs:            
            try:
                
                driver.execute_script("arguments[0].click();", page_tab)
                time.sleep(.2)
                Redbus_Links = driver.find_elements(By.CLASS_NAME, 'route')
                links += len(Redbus_Links)
                for busroute_link in Redbus_Links:
                    link = busroute_link.get_attribute('href')
                    if link and link.startswith("https://www.redbus.in/bus-tickets/"):
                        bus_link.append(link)
            except Exception as e:
                print(f"Error clicking page tab {page_tab.text}: {e}")
            print(f"Found {(links)} footer links on {url}")   
    return bus_link


def create_table():
    try:
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()
        table_schema = """
        CREATE TABLE IF NOT EXISTS Bus_Routes (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            route_name VARCHAR(255),
            route_link VARCHAR(255),
            bus_name VARCHAR(255),
            bus_type VARCHAR(255),
            departure_time VARCHAR(255),
            duration VARCHAR(255),
            arrival_time VARCHAR(255),
            rating FLOAT,
            price VARCHAR(255),
            availability VARCHAR(255),
            CONSTRAINT Filter Unique('route_name','bus_name','departure_time')
        );
        """
        cursor.execute(table_schema)
        conn.commit()
    except Exception as e:
        print(e)
    finally:
        conn.close()

def drop_table():
    try:
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()
        table_schema = """
        DROP TABLE IF EXISTS Bus_Routes;
        """
        cursor.execute(table_schema)
        conn.commit()
    except Exception as e:
        print(e)
    finally:
        conn.close()

        
def scrape_bus_data(driver, bus_link):
    try:
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()
        bus_data = []

        for i in bus_link:
            try:
                print(i)
                driver.get(i)
                WebDriverWait(driver, 40).until(EC.presence_of_all_elements_located((By.CLASS_NAME, 'row-sec.clearfix')))
                pages = 1
                while 100>pages:
                    buses = len(driver.find_elements(By.CLASS_NAME, 'row-sec.clearfix')) 
                    # print(buses)
                    pages+=1   
                    driver.execute_script("window.scrollBy(0, 500)")    
                    
                buses = driver.find_elements(By.CLASS_NAME, 'row-sec.clearfix')
                print(f"Found {len(buses)} buses on page {i}")
                
                for bus in buses:
                    try:
                        bus_name = bus.find_element(
                            By.CLASS_NAME, 'travels.lh-24.f-bold.d-color').text.strip()
                        bus_type = bus.find_element(
                            By.CLASS_NAME, 'bus-type.f-12.m-top-16.l-color.evBus').text.strip()
                        # departure_time = bus.find_element(
                        #     # dp-time f-19 d-color f-bold
                        #     By.CLASS_NAME, 'column-three.p-right-10.w-10.fl').text.strip()
                        departure_time = bus.find_element(
                            By.CLASS_NAME, 'dp-time.f-19.d-color.f-bold').text.strip()

                        # duration = bus.find_element(
                        #     By.CLASS_NAME, 'column-five.p-right-10.w-10.fl').text.strip()
                        duration = bus.find_element(
                            By.CLASS_NAME, 'dur.l-color.lh-24').text.strip()
                        # arrival_time = bus.find_element(
                        #     By.CLASS_NAME, 'column-five.p-right-10.w-10.fl').text.strip()
                        arrival_time = bus.find_element(
                            By.CLASS_NAME, 'bp-time.f-19.d-color.disp-Inline').text.strip()
                        try:
                            rating = bus.find_element(
                                By.CLASS_NAME, 'rating-sec.lh-24').text.strip()
                        except:
                            rating = 0
                        price = float(bus.find_element(
                            By.CLASS_NAME, 'fare.d-block').text.strip().lower().replace('inr ', ''))

                        try:
                            availability = bus.find_element(
                                By.CLASS_NAME, 'seat-left.m-top-30').text.strip()
                        except:
                            availability = bus.find_element(
                                By.CLASS_NAME, 'seat-left.m-top-16').text.strip()

                        if bus_name and price:  # Ensure critical elements are found
                            bus_data = {
                                'route_name': i[34:],
                                'route_link': i,
                                'bus_name': bus_name,
                                'bus_type': bus_type,
                                'departure_time': departure_time,
                                'duration': duration,
                                'arrival_time': arrival_time,
                                'rating': rating,
                                'price': price,
                                'availability': availability
                            }
                            insert_into_table(bus_data,cursor,conn)
                            print(f"Added bus: {bus_name}")
                        else:
                            print(f"Skipping incomplete data for bus on page {i}")

                    except Exception as e:
                        print(f"Error scraping bus data: {e}")

            except Exception as e:
                print(f"Error loading page {i}: {e}")
    except Exception as e:
        print(e)
    finally:
        conn.close()

    return bus_data


driver = webdriver.Chrome()

urls = [
    'https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/astc/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile',
    'https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu',
    'https://www.redbus.in/online-booking/west-bengal-transport-corporation',
    'https://www.redbus.in/online-booking/north-bengal-state-transport-corporation',
    'https://www.redbus.in/online-booking/meghalaya-transport-corporation-mtc'
]

try:
    bus_link = get_bus_links(driver, urls)
    print(f"Collected {len(bus_link)} bus links")

    if bus_link:
        choice = int(input('Press 1 to recreate db, Press 2 to append to old db'))
        if choice == 1:
            drop_table()
            create_table()
            bus_data = scrape_bus_data(driver, bus_link)
        elif choice == 2:
            bus_data = scrape_bus_data(driver, bus_link)
        print(bus_data)
    else:
        print("No bus links found.")

except Exception as e:
    print(f"Unexpected error: {e}")

finally:
    driver.quit()
# Out:
# Found 10 footer links on https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile
# Found 30 footer links on https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile
# Found 40 footer links on https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile
# Found 49 footer links on https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile
# Found 19 footer links on https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile
# Found 26 footer links on https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile
# Found 30 footer links on https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile
# Found 40 footer links on https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile
# Found 21 footer links on https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile
# Found 30 footer links on https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile
# Found 40 footer links on https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile
# Found 45 footer links on https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile
# Found 30 footer links on https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile
# Found 40 footer links on https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile
# Found 41 footer links on https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/astc/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/astc/?utm_source=rtchometile
# Found 30 footer links on https://www.redbus.in/online-booking/astc/?utm_source=rtchometile
# Found 40 footer links on https://www.redbus.in/online-booking/astc/?utm_source=rtchometile
# Found 47 footer links on https://www.redbus.in/online-booking/astc/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile
# Found 20 footer links on https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile
# Found 30 footer links on https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile
# Found 40 footer links on https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile
# Found 49 footer links on https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile
# Found 10 footer links on https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu
# Found 20 footer links on https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu
# Found 30 footer links on https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu
# Found 40 footer links on https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu
# Found 49 footer links on https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu
# Found 10 footer links on https://www.redbus.in/online-booking/north-bengal-state-transport-corporation
# Found 20 footer links on https://www.redbus.in/online-booking/north-bengal-state-transport-corporation
# Found 30 footer links on https://www.redbus.in/online-booking/north-bengal-state-transport-corporation
# Found 40 footer links on https://www.redbus.in/online-booking/north-bengal-state-transport-corporation
# Found 49 footer links on https://www.redbus.in/online-booking/north-bengal-state-transport-corporation
# Found 10 footer links on https://www.redbus.in/online-booking/meghalaya-transport-corporation-mtc
# Found 15 footer links on https://www.redbus.in/online-booking/meghalaya-transport-corporation-mtc
# Collected 450 bus links
# https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad
# Found 171 buses on page https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad
# Added bus: IntrCity SmartBus
# Added bus: FRESHBUS
# Added bus: IntrCity SmartBus
# Added bus: AdIntrCity SmartBus
# Added bus: FRESHBUS
# Added bus: FRESHBUS
# Added bus: IntrCity SmartBus
# Added bus: AdSai RK Travels
# Added bus: NueGo
# Added bus: Sri Sanvi Tours and Travels
# Added bus: IntrCity SmartBus
# Added bus: FRESHBUS
# Added bus: Sri Durga Malleswari Travels
# Added bus: Zingbus Plus
# Added bus: NueGo
# Added bus: FRESHBUS
# Added bus: IntrCity SmartBus
# Added bus: FRESHBUS
# Added bus: IntrCity SmartBus
# Added bus: Svkdt travels
# Added bus: NueGo
# Added bus: GMRK Tours and Travels
# Added bus: NueGo
# Added bus: Svkdt travels
# Added bus: NueGo
# Added bus: Tirumala Xpress
# Added bus: BSR Tours And Travels
# Added bus: Sri KVR Travels
# Added bus: NueGo
# Added bus: Yolo Bus
# Added bus: Sri Sai Srinivasa Travels
# Added bus: Svkdt travels
# Added bus: Sri KVR Travels
# Added bus: NueGo
# Added bus: V Kaveri Travels
# Added bus: Anjani Bus
# Added bus: NueGo
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri KVR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: NueGo
# Added bus: Orange Tours And Travels
# Added bus: Morning Star Travels
# Added bus: Orange Tours And Travels
# Added bus: YNR Travels
# Added bus: Royal Varma Travels
# Added bus: Sri Durga Malleswari Travels
# Added bus: NueGo
# Added bus: LVP Travels
# Added bus: Orange Tours And Travels
# Added bus: Orange Tours And Travels
# Added bus: Sri Venkata Padmavathi Travels
# Added bus: Orange Tours And Travels
# Added bus: Venkteshwara Travels
# Added bus: NueGo
# Added bus: Go Tour Travels and Holidays
# Added bus: Sri Atluri Travels
# Added bus: Sudha Sri Tours and Travels
# Added bus: Nani Svkdt Travels
# Added bus: Orange Tours And Travels
# Added bus: KKaveri Travels
# Added bus: NueGo
# Added bus: Eswar Travels
# Added bus: Morning Star Travels
# Added bus: Chandu Travels
# Added bus: Morning Star Travels
# Added bus: Mayuri Travels
# Added bus: Sai Srinivasa Travels
# Added bus: Sri KVR Travels
# Added bus: V Kaveri Travels
# Added bus: Zingbus Plus
# Added bus: Nani’s Sai Krishna Travels
# Added bus: Kaveri Travels
# Added bus: Morning Star Travels
# Added bus: Orange Tours And Travels
# Added bus: Orange Tours And Travels
# Added bus: Holidays Tours and Travels
# Added bus: Moonlight Travels
# Added bus: Sri Venkata Padmavathi Travels
# Added bus: Vahini Travels
# Added bus: Sai Srinivasa Travels
# Added bus: Morning Star Travels
# Added bus: Sai RK Travels
# Added bus: Morning Star Travels
# Added bus: Sri Atluri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri KVR Travels
# Added bus: Sai Sri Durga Travels
# Added bus: Komali Travels
# Added bus: Orange Tours And Travels
# Added bus: GO BUS
# Added bus: Morning Star Travels
# Added bus: BSR Tours And Travels
# Added bus: Sai Dasari Travels
# Added bus: Navayuga Travels
# Added bus: Laharisa Tours and Travels
# Added bus: Prasanna Travels
# Added bus: Orange Tours And Travels
# Added bus: LVP Travels
# Added bus: KKaveri Travels
# Added bus: Apple Travels
# Added bus: Sai RK Travels
# Added bus: Ramana Tours And Travels
# Added bus: Ramana Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: J Gagana Travels
# Added bus: Sri Sai Anjana Tours and Travels
# Added bus: Mahi Trans Solutions
# Added bus: Orange Tours and Travels Grand
# Added bus: LVR Travels
# Added bus: Sree Gowtham Travels
# Added bus: IntrCity SmartBus
# Added bus: Royal Varma Travels
# Added bus: Chandu Travels
# Added bus: Padma Travels
# Added bus: Krk Travels
# Added bus: Sri NVR Travels
# Added bus: SREE KARA TRAVELS
# Added bus: Sri Atluri Travels
# Added bus: Sri KVR Travels
# Added bus: KTR Travels
# Added bus: Siri Tours and Travels
# Added bus: Sri KVR Travels
# Added bus: Siri Tours and Travels
# Added bus: Sitara Travels
# Added bus: Sri KVR Travels
# Added bus: DMR Travels
# Added bus: DMR Travels
# Added bus: DMR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Vahini Travels
# Added bus: Mahi Trans Solutions
# Added bus: Komali Travels
# Added bus: AVR Travels
# Added bus: SVM Tours And Travels
# Added bus: Sai Godavari Travels
# Added bus: Meghana Travels
# Added bus: Prasanna Travels
# Added bus: Morning Star Travels
# Added bus: Sri KVR Travels
# Added bus: Morning Star Travels
# Added bus: Morning Star Travels
# Added bus: Shri Ganesh Travels
# Added bus: Vinay's Tours and Travels
# Added bus: Sai Sri Krishna Travels
# Added bus: Morning Star Travels
# Added bus: SS Prasanna Travels
# Added bus: Vinay's Tours and Travels
# Added bus: Sri Atluri Travels
# Added bus: SSK Travels
# Added bus: Rainbow Tours And Travels
# Added bus: AVR Travels
# Added bus: Rainbow Tours And Travels
# Added bus: Sai Dasari Travels
# Added bus: Sri Krishna Travels
# Added bus: SAMANVI CITICONNECT
# Added bus: V Kaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Srivastav Travels
# Added bus: Sri KVR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sree Durga Kaveri Travels
# Added bus: Dharani Tours and Travels
# Added bus: ARK Travels
# Added bus: Meghana Travels
# Added bus: Prasanna Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sai Dasari Travels
# Added bus: Surya Dream Liner
# Added bus: Sree Raghavendra Travels
# https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada
# Found 240 buses on page https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada
# Added bus: Svkdt travels
# Added bus: IntrCity SmartBus
# Added bus: FRESHBUS
# Added bus: AdSri Sanvi Tours and Travels
# Added bus: IntrCity SmartBus
# Added bus: IntrCity SmartBus
# Added bus: IntrCity SmartBus
# Added bus: FRESHBUS
# Added bus: FRESHBUS
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: FRESHBUS
# Added bus: FRESHBUS
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: IntrCity SmartBus
# Added bus: NueGo
# Added bus: IntrCity SmartBus
# Added bus: NueGo
# Added bus: Sri KVR Travels
# Added bus: NueGo
# Added bus: NueGo
# Added bus: Sri Durga Malleswari Travels
# Added bus: Zingbus Plus
# Added bus: NueGo
# Added bus: NueGo
# Added bus: NueGo
# Added bus: FRESHBUS
# Added bus: NueGo
# Added bus: LVP Travels
# Added bus: NueGo
# Added bus: NueGo
# Added bus: IntrCity SmartBus
# Added bus: LVR Travels
# Added bus: Yolo Bus
# Added bus: Tirumala Xpress
# Added bus: Sri KVR Travels
# Added bus: V Kaveri Travels
# Added bus: NueGo
# Added bus: Sri KVR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Orange Tours And Travels
# Added bus: Orange Tours And Travels
# Added bus: Go Tour Travels and Holidays
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Orange Tours And Travels
# Added bus: Mythri Tours And Travels
# Added bus: Anjani Bus
# Added bus: Sri Venkata Padmavathi Travels
# Added bus: Sri Durga Malleswari Travels
# Added bus: BSR Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Morning Star Travels
# Added bus: Sai Srinivasa Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: PRK Travels
# Added bus: GO BUS
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Nani Svkdt Travels
# Added bus: Orange Tours And Travels
# Added bus: Sri Atluri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Orange Tours And Travels
# Added bus: Morning Star Travels
# Added bus: Zingbus Plus
# Added bus: Orange Tours And Travels
# Added bus: IntrCity SmartBus
# Added bus: V Kaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: IntrCity SmartBus
# Added bus: Kaveri Travels
# Added bus: Kaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: V Kaveri Travels
# Added bus: SLGT Travels
# Added bus: Elegance Tours And Travels Pvt Ltd
# Added bus: Sri Sai Srinivasa Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Added bus: Sudha Sri Tours and Travels
# Added bus: Eswar Travels
# Added bus: Royal Varma Travels
# Added bus: Sai RK Travels
# Added bus: Orange Tours And Travels
# Added bus: CVR Express
# Added bus: LVP Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sitara Travels
# Added bus: Chandu Travels
# Added bus: Sri Rama Travels
# Added bus: SAMANVI CITICONNECT
# Added bus: Sai Srinivasa Travels
# Added bus: LVR Travels
# Added bus: Sri Venkata Padmavathi Travels
# Added bus: IntrCity SmartBus
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sai Srinivasa Travels
# Added bus: IntrCity SmartBus
# Added bus: KVR Tours and Travels
# Added bus: SVR Tours and Travels
# Added bus: Komali Travels
# Added bus: Orange Tours And Travels
# Added bus: Sri KVR Travels
# Added bus: Tirumala Travels
# Added bus: V Kaveri Travels
# Added bus: Sri KVR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Zingbus Plus
# Added bus: Srivastav Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Orange Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Siri Tours and Travels
# Added bus: Siri Tours and Travels
# Added bus: Sri Rama Travels
# Added bus: J Gagana Travels
# Added bus: KKaveri Travels
# Added bus: BSR Tours And Travels
# Added bus: Sai Sri Durga Travels
# Added bus: LVP Travels
# Added bus: Navayuga Travels
# Added bus: Sri KVR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: V Kaveri Travels
# Added bus: Mayuri Travels
# Added bus: Sri KVR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: KKaveri Travels
# Added bus: Nani’s Sai Krishna Travels
# Added bus: Sri Karan Sai Tours and Travels
# Added bus: Orange Tours And Travels
# Added bus: Puri Jagannadh Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Mayuri Travels
# Added bus: SAMANVI CITICONNECT
# Added bus: Ramana Tours And Travels
# Added bus: KKaveri Travels
# Added bus: Kaveri Travels
# Added bus: Sai RK Travels
# Added bus: LIMOLINER
# Added bus: Ramana Tours And Travels
# Added bus: Apple Travels
# Added bus: Siri Tours and Travels
# Added bus: Sai Dasari Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Navayuga Travels
# Added bus: Sri Keerthana Sai Travels
# Added bus: Morning Star Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: V Kaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Mayuri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: KKaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Jagan Travels
# Added bus: Orange Tours And Travels
# Added bus: Mythri Tours And Travels
# Added bus: Sree Gowtham Travels
# Added bus: Neelachal Travels
# Added bus: IntrCity SmartBus
# Added bus: Svkdt travels
# Added bus: IntrCity SmartBus
# Added bus: GMC Travels
# Added bus: Padma Travels
# Added bus: Jayanthi Travels
# Added bus: Shree Manikanta Travels
# Added bus: Jayanthi Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Jayanthi Travels
# Added bus: Krk Travels
# Added bus: Sri KVR Travels
# Added bus: Sri KVR Travels
# Added bus: BSR Tours And Travels
# Added bus: Sri Atluri Travels
# Added bus: Sri Atluri Travels
# Added bus: SANDHYA TRAVELS
# Added bus: Laharisa Tours and Travels
# Added bus: Sai Virat Travels
# Added bus: Sai Srinivasa Travels
# Added bus: Navayuga Travels
# Added bus: Vahini Travels
# Added bus: Sri NVR Travels
# Added bus: Srivastav Travels
# Added bus: Vahini Travels
# Added bus: SREE KARA TRAVELS
# Added bus: Sri Sai Anjana Tours and Travels
# Added bus: Sri Sai Anjana Tours and Travels
# Added bus: KTR Travels
# Added bus: Kalyani Transport
# Added bus: CVR Travels
# Added bus: DMR Travels
# Added bus: DMR Travels
# Added bus: DMR Travels
# Added bus: Vinay's Tours and Travels
# Added bus: Sri Tulasi Tours and Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: KVR Tours and Travels
# Added bus: Sri Tulasi Tours and Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sai Godavari Travels
# Added bus: Puri Jagannadh Tours And Travels
# Added bus: Puri Jagannadh Tours And Travels
# Added bus: SVM Tours And Travels
# Added bus: Chandu Travels
# Added bus: Royal Varma Travels
# Added bus: Ajay Bus
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Vinay's Tours and Travels
# Added bus: Siri Tours and Travels
# Added bus: Siri Tours and Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Meghana Travels
# Added bus: Mayuri Travels
# Added bus: Mayuri Travels
# Added bus: Mayuri Travels
# Added bus: Mayuri Travels
# Added bus: Rainbow Tours And Travels
# Added bus: Sai RK Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: V Kaveri Travels
# Added bus: Bmcc Travels
# Added bus: Jayanthi Travels
# Added bus: Sai Sri Krishna Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: KKaveri Travels
# Added bus: Ramana Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Ramana Tours And Travels
# Added bus: Tranzindia Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# https://www.redbus.in/bus-tickets/kakinada-to-visakhapatnam
# Found 2 buses on page https://www.redbus.in/bus-tickets/kakinada-to-visakhapatnam
# Added bus: Vahini Travels
# Added bus: SRI VIJAYA KRISHNA TOURS and TRAVELS
# https://www.redbus.in/bus-tickets/visakhapatnam-to-kakinada
# Found 5 buses on page https://www.redbus.in/bus-tickets/visakhapatnam-to-kakinada
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Sai RK Travels
# Added bus: SRI VIJAYA KRISHNA TOURS and TRAVELS
# Added bus: Navayuga Travels
# Added bus: Morning Star Travels
# https://www.redbus.in/bus-tickets/chittoor-andhra-pradesh-to-bangalore
# Found 7 buses on page https://www.redbus.in/bus-tickets/chittoor-andhra-pradesh-to-bangalore
# Added bus: NueGo
# Added bus: SRS Travels
# Added bus: NueGo
# Added bus: NueGo
# Added bus: NueGo
# Added bus: Varsha Travels
# Added bus: RK Travels
# https://www.redbus.in/bus-tickets/kadapa-to-bangalore
# Found 35 buses on page https://www.redbus.in/bus-tickets/kadapa-to-bangalore
# Added bus: Sri Vinayaka Travels
# Added bus: Maheswari Travels
# Added bus: S R Travels
# Added bus: PRL BUS
# Added bus: AR & BCVR Travels
# Added bus: INDHU BUS
# Added bus: Maheswari Travels
# Added bus: AR & BCVR Travels
# Added bus: Indu Travels
# Added bus: HARITHA TRAVELS
# Added bus: V Kaveri Travels
# Added bus: Indu Travels
# Added bus: CGR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Abhishek Bus
# Added bus: BHAIRAVA TOURS AND TRAVELS
# Added bus: Sri Vengamamba Bus Transport(SVBT)
# Added bus: Royal Voyage Travels (RVT)
# Added bus: Giridhar Tours and Travels
# Added bus: Sri Shrinivasa Bus Transport (SSBT)
# Added bus: Sri Vengamamba Bus Transport(SVBT)
# Added bus: Sri Vengamamba Bus Transport(SVBT)
# Added bus: SLNS Travels
# Added bus: Sri Shrinivasa Bus Transport (SSBT)
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: V Kaveri Travels
# Added bus: S R Travels
# Added bus: Amala Travels
# Added bus: AR & BCVR Travels
# Added bus: Ahobila Travels
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: AR & BCVR Travels
# Added bus: Golden Travels
# https://www.redbus.in/bus-tickets/ananthapur-to-bangalore
# Found 22 buses on page https://www.redbus.in/bus-tickets/ananthapur-to-bangalore
# Added bus: YAS TOURS AND TRAVELS
# Added bus: Kallada Travels (Suresh Kallada)
# Added bus: Orange Tours and Travels Platinum
# Added bus: Orange Tours And Travels
# Added bus: Kallada Travels (Suresh Kallada)
# Added bus: Kallada Travels (Suresh Kallada)
# Added bus: Amala Travels
# Added bus: Kallada Travels (Suresh Kallada)
# Added bus: YAS TOURS AND TRAVELS
# Added bus: YAS TOURS AND TRAVELS
# Added bus: Dream Line Travels Pvt Ltd
# Added bus: OVR Travels
# Added bus: Kallada Travels (Suresh Kallada)
# Added bus: Orange Tours And Travels
# Added bus: YAS TOURS AND TRAVELS
# Added bus: Kallada Travels (Suresh Kallada)
# Added bus: Kallada Travels (Suresh Kallada)
# Added bus: Sri Tulasi Tours and Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Delta Transports Pvt Ltd
# Added bus: Northern Travels
# https://www.redbus.in/bus-tickets/tirupathi-to-bangalore
# Found 67 buses on page https://www.redbus.in/bus-tickets/tirupathi-to-bangalore
# Added bus: FRESHBUS
# Added bus: FRESHBUS
# Added bus: Vibhav Holidays
# Added bus: Vibhav Holidays
# Added bus: NueGo
# Added bus: NueGo
# Added bus: FRESHBUS
# Added bus: NueGo
# Added bus: FRESHBUS
# Added bus: GreenLine Travels And Holidays
# Added bus: Varsha Travels
# Added bus: RK Travels
# Added bus: GreenLine Travels And Holidays
# Added bus: SRI RATAN TATA EXPRESS
# Added bus: RCV Travels
# Added bus: Abhishek Bus
# Added bus: NueGo
# Added bus: RK Travels
# Added bus: Abhishek Bus
# Added bus: NueGo
# Added bus: FRESHBUS
# Added bus: VEGA BUS
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: METRO LINES TRAVELS
# Added bus: Vihari Travels
# Added bus: GKT TRAVELS
# Added bus: AKHILA TRAVELS
# Added bus: GreenLine Travels And Holidays
# Added bus: AGR Travels
# Added bus: Jabbar Travels
# Added bus: Sri Vinayaka Travels
# Added bus: Jabbar Travels
# Added bus: Dhriti Travels
# Added bus: KTC Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Rapid Travels
# Added bus: Rajeswari Travels
# Added bus: KKaveri Travels
# Added bus: Bharathi Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Simhapuri Travels
# Added bus: JTS Tours and Travels
# Added bus: Rapid Travels
# Added bus: Rajeswari Travels
# Added bus: GreenLine Travels And Holidays
# Added bus: CHOPPA TRAVELS
# Added bus: GreenLine Travels And Holidays
# Added bus: MRS TRAVELS
# Added bus: BSRM Travels
# Added bus: CHOPPA TRAVELS
# Added bus: Rajesh Transports
# Added bus: GreenLine Travels And Holidays
# Added bus: Sai Sindhu Travels
# Added bus: Go Tour Travels and Holidays
# Added bus: Abhishek Bus
# Added bus: Rajesh Transports
# Added bus: GRV Yatrikha LLP
# Added bus: Green Line Travels And Holidays Premium Business Class
# Added bus: Dream Line Travels Pvt Ltd
# Added bus: Manis Travels
# Added bus: KGN and NR TRAVELS
# Added bus: GEETHA TRAVELS
# Added bus: Padmavathi Travels
# Added bus: GreenLine Travels And Holidays
# Added bus: NAS Travels
# Added bus: Svkdt travels
# Added bus: Rajeswari Travels
# https://www.redbus.in/bus-tickets/visakhapatnam-to-vijayawada
# Found 172 buses on page https://www.redbus.in/bus-tickets/visakhapatnam-to-vijayawada
# Added bus: IntrCity SmartBus
# Added bus: Yolo Bus
# Added bus: Svkdt travels
# Added bus: Svkdt travels
# Added bus: Svkdt travels
# Added bus: IntrCity SmartBus
# Added bus: Svkdt travels
# Added bus: Yolo Bus
# Added bus: NueGo
# Added bus: NueGo
# Added bus: Sai Sri Krishna Travels
# Added bus: Svkdt travels
# Added bus: Zingbus Plus
# Added bus: Sri KVR Travels
# Added bus: NueGo
# Added bus: Sri KVR Travels
# Added bus: NueGo
# Added bus: Svkdt travels
# Added bus: Sri Amaravathi Travels
# Added bus: Sri KVR Travels
# Added bus: Sri Venkataramana Travels
# Added bus: Sai Balaji Travels
# Added bus: Morning Star Travels
# Added bus: Sri Krishna Travels
# Added bus: Sri KVR Travels
# Added bus: Sri Padmavathi Travels
# Added bus: Prathap Travels
# Added bus: Orange Tours and Travels Platinum
# Added bus: Orange Tours And Travels
# Added bus: Morning Star Travels
# Added bus: IntrCity SmartBus
# Added bus: IntrCity SmartBus
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Added bus: Svkdt travels
# Added bus: IRA Travels
# Added bus: VV Vinayak Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Padmavathi Travels
# Added bus: Sri Krishna Travels
# Added bus: Sri Venkataramana Travels
# Added bus: IntrCity SmartBus
# Added bus: PRL BUS
# Added bus: Elegance Tours And Travels Pvt Ltd
# Added bus: RAJULATALLI TRAVELS
# Added bus: Zingbus Plus
# Added bus: Sri Padmavathi Travels
# Added bus: Orange Tours And Travels
# Added bus: IntrCity SmartBus
# Added bus: Sri KVR Travels
# Added bus: LAVYASRI Travels
# Added bus: NueGo
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Mayuri Travels
# Added bus: Zingbus Plus
# Added bus: Rajesh Transports
# Added bus: KKaveri Travels
# Added bus: Sri Venkataramana Travels
# Added bus: Sri KVR Travels
# Added bus: Sri Padmavathi Travels
# Added bus: Nani’s Sai Krishna Travels
# Added bus: Navin Travels
# Added bus: SREE PAVAN TRAVELS
# Added bus: Sai RK Travels
# Added bus: Orange Tours And Travels
# Added bus: SVR Tours and Travels
# Added bus: Sri Venkataramana Travels
# Added bus: Mozo travels
# Added bus: Sri Amaravathi Travels
# Added bus: Vsaikrishna Travels
# Added bus: SREE PAVAN TRAVELS
# Added bus: Sri Padmavathi Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Nani’s Sai Krishna Travels
# Added bus: Prathap Travels
# Added bus: Sai RK Travels
# Added bus: Nani’s Sai Krishna Travels
# Added bus: V Kaveri Travels
# Added bus: V Kaveri Travels
# Added bus: Jagan Travels
# Added bus: KKaveri Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: IntrCity SmartBus
# Added bus: BSR Tours And Travels
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: GMC Travels
# Added bus: Shree Manikanta Travels
# Added bus: Ramana Tours And Travels
# Added bus: LIMOLINER
# Added bus: Shree Manikanta Travels
# Added bus: SAMANVI CITICONNECT
# Added bus: YBM Travels(BLM)
# Added bus: Krk Travels
# Added bus: LUCKY TRAVELS
# Added bus: LUCKY TRAVELS
# Added bus: Navin Travels
# Added bus: Mayuri Travels
# Added bus: Mayuri Travels
# Added bus: Sri KVR Travels
# Added bus: IRA Travels
# Added bus: SRI SAI BALAJI TOURS AND TRAVELS
# Added bus: Sri VInayaka Travels(Siva's)
# Added bus: Rajesh Transports
# Added bus: KTR Travels
# Added bus: SVD Vedansh Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: RUDRA TOURS & TRAVELS
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Sri KVR Travels
# Added bus: SRI RATAN TATA EXPRESS
# Added bus: Navayuga Travels
# Added bus: Navayuga Travels
# Added bus: Navayuga Travels
# Added bus: KKaveri Travels
# Added bus: KKaveri Travels
# Added bus: Sree Durga Kaveri Travels
# Added bus: Sai Sri Krishna Travels
# Added bus: Sri Keerthana Sai Travels
# Added bus: Navin Citi Connect
# Added bus: Sri Keerthana Sai Travels
# Added bus: Orange Tours And Travels
# Added bus: Sri KVR Travels
# Added bus: Sri Padmavathi Travels
# Added bus: Morning Star Travels
# Added bus: Morning Star Travels
# Added bus: Bmcc Travels
# Added bus: Sri Laxmi Sravanthi Siva Tours And Travels
# Added bus: Sai Dasari Travels
# Added bus: SJR TRAVELS
# Added bus: Sri Amaravathi Travels
# Added bus: Sai RK Travels
# Added bus: V Kaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: V Kaveri Travels
# Added bus: V Kaveri Travels
# Added bus: KVR Tours and Travels
# Added bus: Sri Dhanalakshmi Travels
# Added bus: New Sindhu Travels
# Added bus: SKS Logistics
# Added bus: Kaveri Travels
# Added bus: Vikram Travels
# Added bus: Sree Sambasiva Tours and Travels
# Added bus: Cherry Collars
# Added bus: Jagan Travels
# Added bus: Jagan Travels
# Added bus: Sri Dhanalakshmi Travels
# Added bus: Navin Travels
# Added bus: Jaishree Travels
# Added bus: Sri VInayaka Travels(Siva's)
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Added bus: BEZAWADA TOURS AND TRAVELS
# Added bus: KKaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: ARK Travels
# Added bus: Morning Star Travels
# Added bus: SKS Logistics
# Added bus: Sree Sambhavi Tours and Travels
# Added bus: Sri Dhanalakshmi Travels
# Added bus: New Sindhu Travels
# Added bus: Sri Dhanalakshmi Travels
# Added bus: Naveen Tours and Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: VRL Travels
# Added bus: VRL Travels
# https://www.redbus.in/bus-tickets/ongole-to-hyderabad
# Found 93 buses on page https://www.redbus.in/bus-tickets/ongole-to-hyderabad
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: V Kaveri Travels
# Added bus: Kaveri Travels
# Added bus: Orange Tours And Travels
# Added bus: Chandu Travels
# Added bus: Sri Krishna Travels
# Added bus: Kamakshi Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: V Kaveri Travels
# Added bus: Sri Krishna Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Added bus: KKaveri Travels
# Added bus: Vikram Travels
# Added bus: Kaveri Travels
# Added bus: V Kaveri Travels
# Added bus: VV Vinayak Travels
# Added bus: Kaveri Travels
# Added bus: Sri Sahasra Tours and Travels
# Added bus: Mozo travels
# Added bus: KKaveri Travels
# Added bus: Jagan Travels
# Added bus: Padmavathi Travels
# Added bus: My Star Transport
# Added bus: KKaveri Travels
# Added bus: Morning Star Travels
# Added bus: KTC Travels
# Added bus: Vihari Travels
# Added bus: Sri Krishna Travels
# Added bus: Sri Krishna Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: KMBT Travels
# Added bus: Sri Lakshmi Narshima Travels
# Added bus: V Kaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Vihari Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Cherry tours&travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Cherry tours&travels
# Added bus: Sri Lakshmi Narshima Travels
# Added bus: VV Vinayak Travels
# Added bus: Kaveri Travels
# Added bus: Sri Lakshmi Narshima Travels
# Added bus: Meghana Travels
# Added bus: SAI PRASANNA TRAVELS
# Added bus: KMBT Travels
# Added bus: KKaveri Travels
# Added bus: Sri Sivanjali Bus
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: VV Vinayak Travels
# Added bus: Sri Laxmi Sravanthi Siva Tours And Travels
# Added bus: Sri Lakshmi Narshima Travels
# Added bus: Orange Tours And Travels
# Added bus: Sri Laxmi Sravanthi Siva Tours And Travels
# Added bus: VV Vinayak Travels
# Added bus: KKaveri Travels
# Added bus: Vihari Travels
# Added bus: V Kaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Added bus: SRI SVR travels
# Added bus: Sri Krishna Travels
# Added bus: Sri Krishna Travels
# Added bus: KMBT Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: VV Vinayak Travels
# Added bus: Rajeswari Travels
# Added bus: Ramu Tours & Travels
# Added bus: V Kaveri Travels
# Added bus: Cherry tours&travels
# Added bus: Vihari Travels
# Added bus: SBT
# Added bus: Ramu Tours & Travels
# Added bus: Ramu Tours & Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Laxmi Sravanthi Siva Tours And Travels
# Added bus: Vihari Tours And Travels
# Added bus: Vihari Tours And Travels
# Added bus: Vihari Tours And Travels
# Added bus: METRO LINES TRAVELS
# Added bus: Vihari Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Padmavathi Travels
# Added bus: Rajeswari Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Rajeswari Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Laxmi Sravanthi Siva Tours And Travels
# https://www.redbus.in/bus-tickets/bangalore-to-tirupathi
# Found 163 buses on page https://www.redbus.in/bus-tickets/bangalore-to-tirupathi
# Added bus: NueGo
# Added bus: FRESHBUS
# Added bus: NueGo
# Added bus: Yolo Bus
# Added bus: Shree Manikanta Travels
# Added bus: Jagan Travels
# Added bus: Jabbar Travels
# Added bus: FRESHBUS
# Added bus: Rajesh Transports
# Added bus: Sri KVR Travels
# Added bus: IntrCity SmartBus
# Added bus: NueGo
# Added bus: Abhishek Bus
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Sri Krishna Travels
# Added bus: VEGA BUS
# Added bus: RK Travels
# Added bus: IntrCity SmartBus
# Added bus: MRS TRAVELS
# Added bus: BSRM Travels
# Added bus: FRESHBUS
# Added bus: CHOPPA TRAVELS
# Added bus: RK Travels
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: Abhishek Bus
# Added bus: IntrCity SmartBus
# Added bus: Kaveri Travels
# Added bus: KMBT Travels
# Added bus: Sai Sri Balaji Travels
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: ASHITHA TRAVELS
# Added bus: CCC Bus
# Added bus: GreenLine Travels And Holidays
# Added bus: Vihari Travels
# Added bus: Zingbus Plus
# Added bus: AGR Travels
# Added bus: Go Tour Travels and Holidays
# Added bus: IntrCity SmartBus
# Added bus: Bharathi Travels
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: AKHILA TRAVELS
# Added bus: Intercity travels
# Added bus: GKT TRAVELS
# Added bus: KTC Travels
# Added bus: FRESHBUS
# Added bus: VEGA BUS
# Added bus: AKHILA TRAVELS
# Added bus: LUCKY TRAVELS
# Added bus: Jabbar Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: GreenLine Travels And Holidays
# Added bus: NueGo
# Added bus: Sri Vinayaka Travels
# Added bus: FRESHBUS
# Added bus: JTS Tours and Travels
# Added bus: Rajeswari Travels
# Added bus: Rajesh Transports
# Added bus: NueGo
# Added bus: FRESHBUS
# Added bus: Zingbus Plus
# Added bus: KKaveri Travels
# Added bus: Sai Sri Durga Travels
# Added bus: Yolo Bus
# Added bus: Komitla Trans lines.
# Added bus: Orange Tours And Travels
# Added bus: SRS Travels
# Added bus: Orange Tours and Travels Grand
# Added bus: Svkdt travels
# Added bus: Abhishek Bus
# Added bus: SRKT Travels
# Added bus: Jagan Travels
# Added bus: CHAITRA SRI TRAVELS
# Added bus: Svkdt travels
# Added bus: Varsha Travels
# Added bus: SRKT Travels
# Added bus: Sri Venkataramana Travels
# Added bus: V Kaveri Travels
# Added bus: GreenLine Travels And Holidays
# Added bus: Komitla Trans lines.
# Added bus: KMBT Travels
# Added bus: Varsha Travels
# Added bus: Komitla Trans lines.
# Added bus: Balaji Tourist
# Added bus: Rapid Travels
# Added bus: Svkdt travels
# Added bus: SRI RATAN TATA EXPRESS
# Added bus: GRV Yatrikha LLP
# Added bus: KKaveri Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Rapid Travels
# Added bus: Simhapuri Travels
# Added bus: Varsha Travels
# Added bus: SVD Vedansh Travels
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Rajesh Transports
# Added bus: Orange Tours and Travels Platinum
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Sri Tulasi Tours and Travels
# Added bus: Rajesh Transports
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Added bus: Sai Balaji Travels
# Added bus: Navayuga Travels
# Added bus: Rajesh Transports
# Added bus: Intercity travels
# Added bus: Prasanna Travels
# Added bus: Sri Krishna Travels
# Added bus: Rajesh Transports
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: IntrCity SmartBus
# Added bus: Chalasani Travels (Kaleswari)
# Added bus: Intercity travels
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: CCC Bus
# Added bus: Rajesh Transports
# Added bus: BNR Travels
# Added bus: Sri Vengamamba Bus Transport (SVBT)
# Added bus: Sri Krishna Travels
# Added bus: Kamakshi Tours And Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: METRO LINES TRAVELS
# Added bus: Rajesh Transports
# Added bus: Chalasani Travels (Kaleswari)
# Added bus: Abhishek Bus
# Added bus: GreenLine Travels And Holidays
# Added bus: Sri Krishna Travels
# Added bus: IntrCity SmartBus
# Added bus: Rajesh Transports
# Added bus: BNR Travels
# Added bus: Rajesh Transports
# Added bus: GreenLine Travels And Holidays
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Sri Krishna Travels
# Added bus: Dream Line Travels Pvt Ltd
# Added bus: GreenLine Travels And Holidays
# Added bus: Green Line Travels And Holidays Premium Business Class
# Added bus: Sai Sindhu Travels
# Added bus: GreenLine Travels And Holidays
# Added bus: Rajesh Transports
# Added bus: V Kaveri Travels
# Added bus: SRI RATAN TATA EXPRESS
# Added bus: Navayuga Travels
# Added bus: Morning Star Travels
# Added bus: Svkdt travels
# Added bus: Morning Star Travels
# Added bus: IRA Travels
# Added bus: GreenLine Travels And Holidays
# Added bus: Sree Hari Travels
# Added bus: Varsha Travels
# Added bus: KGN and NR TRAVELS
# Added bus: GEETHA TRAVELS
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Durga Shree Travels
# Added bus: Varsha Travels
# Added bus: Morning Star Travels
# Added bus: KGN and NR TRAVELS
# Added bus: NAS Travels
# Added bus: V Kaveri Travels
# Added bus: IRA Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri Krishna Travels
# Added bus: VRL Travels
# Added bus: VRL Travels
# https://www.redbus.in/bus-tickets/macherla-to-hyderabad
# Found 3 buses on page https://www.redbus.in/bus-tickets/macherla-to-hyderabad
# Added bus: IVR Tours and Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Harikrishna Travels
# https://www.redbus.in/bus-tickets/rajahmundry-to-visakhapatnam
# Found 34 buses on page https://www.redbus.in/bus-tickets/rajahmundry-to-visakhapatnam
# Added bus: NueGo
# Added bus: NueGo
# Added bus: IRA Travels
# Added bus: NueGo
# Added bus: SREE PAVAN TRAVELS
# Added bus: Sri Padmavathi Travels
# Added bus: Nani’s Sai Krishna Travels
# Added bus: Sri Padmavathi Travels
# Added bus: Navin Travels
# Added bus: Prathap Travels
# Added bus: Sri Amaravathi Travels
# Added bus: Nani’s Sai Krishna Travels
# Added bus: Sree Durga Kaveri Travels
# Added bus: Sri Padmavathi Travels
# Added bus: Sai Sri Krishna Travels
# Added bus: SRI SAI BALAJI TOURS AND TRAVELS
# Added bus: Nani’s Sai Krishna Travels
# Added bus: Sri KVR Travels
# Added bus: Sri KVR Travels
# Added bus: Sri KVR Travels
# Added bus: Sri KVR Travels
# Added bus: New Sindhu Travels
# Added bus: Sri KVR Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Sri KVR Travels
# Added bus: Sri KVR Travels
# Added bus: Sri KVR Travels
# Added bus: Sri KVR Travels
# Added bus: Sree Sambhavi Tours and Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Navayuga Travels
# Added bus: Sri Dhanalakshmi Travels
# https://www.redbus.in/bus-tickets/nandyala-to-hyderabad
# Found 50 buses on page https://www.redbus.in/bus-tickets/nandyala-to-hyderabad
# Added bus: INDHU BUS
# Added bus: PRL BUS
# Added bus: SLNS Travels
# Added bus: BRS Travels
# Added bus: VEERA BRAHMENDRA TRAVELS
# Added bus: Indu Travels
# Error scraping bus data: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF79EDFEEA2+31554]
# 	(No symbol) [0x00007FF79ED77ED9]
# 	(No symbol) [0x00007FF79EC3872A]
# 	(No symbol) [0x00007FF79EC3E55E]
# 	(No symbol) [0x00007FF79EC40EB1]
# 	(No symbol) [0x00007FF79EC40F50]
# 	(No symbol) [0x00007FF79EC821DB]
# 	(No symbol) [0x00007FF79ECAD02A]
# 	(No symbol) [0x00007FF79EC7BA76]
# 	(No symbol) [0x00007FF79ECAD240]
# 	(No symbol) [0x00007FF79ECCC977]
# 	(No symbol) [0x00007FF79ECACDD3]
# 	(No symbol) [0x00007FF79EC7A33B]
# 	(No symbol) [0x00007FF79EC7AED1]
# 	GetHandleVerifier [0x00007FF79F108B1D+3217341]
# 	GetHandleVerifier [0x00007FF79F155AE3+3532675]
# 	GetHandleVerifier [0x00007FF79F14B0E0+3489152]
# 	GetHandleVerifier [0x00007FF79EEAE776+750614]
# 	(No symbol) [0x00007FF79ED8375F]
# 	(No symbol) [0x00007FF79ED7EB14]
# 	(No symbol) [0x00007FF79ED7ECA2]
# 	(No symbol) [0x00007FF79ED6E16F]
# 	BaseThreadInitThunk [0x00007FFEB441257D+29]
# 	RtlUserThreadStart [0x00007FFEB528AF28+40]
#
# Error scraping bus data: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF79EDFEEA2+31554]
# 	(No symbol) [0x00007FF79ED77ED9]
# 	(No symbol) [0x00007FF79EC3872A]
# 	(No symbol) [0x00007FF79EC3E55E]
# 	(No symbol) [0x00007FF79EC40EB1]
# 	(No symbol) [0x00007FF79EC40F50]
# 	(No symbol) [0x00007FF79EC87F6C]
# 	(No symbol) [0x00007FF79EC8853C]
# 	(No symbol) [0x00007FF79EC7BBAC]
# 	(No symbol) [0x00007FF79ECAD06F]
# 	(No symbol) [0x00007FF79EC7BA76]
# 	(No symbol) [0x00007FF79ECAD240]
# 	(No symbol) [0x00007FF79ECCC977]
# 	(No symbol) [0x00007FF79ECACDD3]
# 	(No symbol) [0x00007FF79EC7A33B]
# ...
# Added bus: Express Line
# Added bus: Lokenath Bus Service
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Rubi Paribahan
# Added bus: Royal Cruiser
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Lokenath Bus Service
# Added bus: Lokenath Bus Service
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: New Dolphin Travels
# Added bus: Sonar Tori
# Added bus: EASY RIDE
# Added bus: Rubi Paribahan
# Added bus: Poulami Paribahan
# Added bus: Lokenath Bus Service
# Added bus: Express Line
# Added bus: Wasim Travels
# Added bus: Padmanabha Paribahan
# Added bus: Swarnali Paribahan
# Added bus: Wasim Travels
# Added bus: Lokenath Bus Service
# Added bus: Aradhana Bus Service
# Added bus: Pammi Travels
# Added bus: Maa Durga Bus Service
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-berhampore
# Found 1 buses on page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-berhampore
# Added bus: NBSTC-COB-BHP-R1-19:00
# https://www.redbus.in/bus-tickets/kolkata-to-cooch-behar-west-bengal
# Found 1 buses on page https://www.redbus.in/bus-tickets/kolkata-to-cooch-behar-west-bengal
# Added bus: NBSTC-KOL-COB-R1-17:00
# https://www.redbus.in/bus-tickets/malda-to-kolkata
# Found 22 buses on page https://www.redbus.in/bus-tickets/malda-to-kolkata
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Express Line
# Added bus: Lokenath Bus Service
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: New Dolphin Travels
# Added bus: New Dolphin Travels
# Added bus: Aitiana Airwings
# Added bus: Sonar Tori
# Added bus: EASY RIDE
# Added bus: Jio Dolphin Travels
# Added bus: Lokenath Bus Service
# Added bus: Padmanabha Paribahan
# Added bus: Modern Travels
# Added bus: Aitiana Airwings
# Added bus: Swarnali Paribahan
# Added bus: Mohanta Travels
# Added bus: Shree Krishna Travels
# Added bus: Lokenath Bus Service
# Added bus: Lokenath Bus Service
# Added bus: Aradhana Bus Service
# Added bus: Wasim Travels
# Added bus: Renuka Travels
# https://www.redbus.in/bus-tickets/berhampore-to-cooch-behar-west-bengal
# Found 2 buses on page https://www.redbus.in/bus-tickets/berhampore-to-cooch-behar-west-bengal
# Added bus: NBSTC-BHP-COB-R1-18:30
# Added bus: Upasana Transport
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-kolkata
# Error loading page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-kolkata: Message:
#
# https://www.redbus.in/bus-tickets/kolkata-to-balurghat
# Found 10 buses on page https://www.redbus.in/bus-tickets/kolkata-to-balurghat
# Added bus: NBSTC-KOL-BLG-R1-19:30
# Added bus: Express Line
# Added bus: Rubi Paribahan
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Sonar Tori
# Added bus: Jio Dolphin Travels
# Added bus: New Dolphin Travels
# Added bus: Padmanabha Paribahan
# Added bus: Swarnali Paribahan
# Added bus: Shree Krishna Travels
# https://www.redbus.in/bus-tickets/berhampore-to-siliguri
# Found 12 buses on page https://www.redbus.in/bus-tickets/berhampore-to-siliguri
# Added bus: NBSTC-BHP-COB-R1-18:30
# Added bus: Aradhana Travels
# Added bus: Lokenath Bus Service
# Added bus: Aradhana Travels
# Added bus: Upasana Transport
# Added bus: RAYAN
# Added bus: RAYAN
# Added bus: Aradhana Bus Service
# Added bus: Upasana Transport
# Added bus: Royal Bus Service
# Added bus: Aradhana Travels
# Added bus: Aradhana Travels
# https://www.redbus.in/bus-tickets/siliguri-to-berhampore
# Found 14 buses on page https://www.redbus.in/bus-tickets/siliguri-to-berhampore
# Added bus: NBSTC-SLG-KOL-R1-18:30
# Added bus: Aradhana Travels
# Added bus: Lokenath Bus Service
# Added bus: Lokenath Bus Service
# Added bus: Lokenath Bus Service
# Added bus: Aradhana Travels
# Added bus: Rubi Paribahan
# Added bus: Upasana Transport
# Added bus: EASY RIDE
# Added bus: Aradhana Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# Added bus: Royal Bus Service
# Added bus: Modern Travels
# Added bus: Aradhana Bus Service
# https://www.redbus.in/bus-tickets/kolkata-to-gangarampur
# Found 6 buses on page https://www.redbus.in/bus-tickets/kolkata-to-gangarampur
# Added bus: NBSTC-KOL-BLG-R1-19:30
# Added bus: Express Line
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Rubi Paribahan
# Added bus: New Dolphin Travels
# Added bus: Swarnali Paribahan
# https://www.redbus.in/bus-tickets/siliguri-to-kalimpong
# Error loading page https://www.redbus.in/bus-tickets/siliguri-to-kalimpong: Message:
#
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-malda
# Found 1 buses on page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-malda
# Added bus: NBSTC-COB-BHP-R1-19:00
# https://www.redbus.in/bus-tickets/malda-to-cooch-behar-west-bengal
# Found 1 buses on page https://www.redbus.in/bus-tickets/malda-to-cooch-behar-west-bengal
# Added bus: NBSTC-BHP-COB-R1-18:30
# https://www.redbus.in/bus-tickets/balurghat-to-kolkata
# Found 10 buses on page https://www.redbus.in/bus-tickets/balurghat-to-kolkata
# Added bus: NBSTC-BLG-KOL-R1-18:30
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: New Dolphin Travels
# Added bus: Sonar Tori
# Added bus: New Dolphin Travels
# Added bus: Jio Dolphin Travels
# Added bus: Swarnali Paribahan
# Added bus: Shree Krishna Travels
# Added bus: Mohanta Travels
# Added bus: Padmanabha Paribahan
# https://www.redbus.in/bus-tickets/kolkata-to-jalpaiguri
# Found 1 buses on page https://www.redbus.in/bus-tickets/kolkata-to-jalpaiguri
# Added bus: NBSTC-KOL-COB-R1-17:00
# https://www.redbus.in/bus-tickets/kolkata-to-islampur-west-bengal
# Found 8 buses on page https://www.redbus.in/bus-tickets/kolkata-to-islampur-west-bengal
# Added bus: Rubi Paribahan
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: EASY RIDE
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Aradhana Bus Service
# Added bus: Express Line
# Added bus: Poulami Paribahan
# Added bus: Poulami Paribahan
# https://www.redbus.in/bus-tickets/falakata-to-berhampore
# Found 1 buses on page https://www.redbus.in/bus-tickets/falakata-to-berhampore
# Added bus: NBSTC-COB-BHP-R1-19:00
# https://www.redbus.in/bus-tickets/kolkata-to-falakata
# Found 1 buses on page https://www.redbus.in/bus-tickets/kolkata-to-falakata
# Added bus: NBSTC-KOL-COB-R1-17:00
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-raiganj
# Found 1 buses on page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-raiganj
# Added bus: NBSTC-COB-BHP-R1-19:00
# https://www.redbus.in/bus-tickets/siliguri-to-cooch-behar-west-bengal
# Error loading page https://www.redbus.in/bus-tickets/siliguri-to-cooch-behar-west-bengal: Message:
#
# https://www.redbus.in/bus-tickets/raiganj-to-krishnanagar
# Found 6 buses on page https://www.redbus.in/bus-tickets/raiganj-to-krishnanagar
# Added bus: NBSTC-RAI-KOL-R1-19:30
# Added bus: Poulami Paribahan
# Added bus: RAYAN
# Added bus: Modern Travels
# Added bus: Lokenath Bus Service
# Added bus: Aradhana Bus Service
# https://www.redbus.in/bus-tickets/raiganj-to-siliguri
# Found 5 buses on page https://www.redbus.in/bus-tickets/raiganj-to-siliguri
# Added bus: Mohanta Travels
# Added bus: Shree Krishna Travels
# Added bus: New Dolphin Travels
# Added bus: Gopal Travels
# Added bus: Padmanabha Travels
# https://www.redbus.in/bus-tickets/kolkata-to-buniadpur
# Found 5 buses on page https://www.redbus.in/bus-tickets/kolkata-to-buniadpur
# Added bus: NBSTC-KOL-BLG-R1-19:30
# Added bus: Express Line
# Added bus: Rubi Paribahan
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: New Dolphin Travels
# https://www.redbus.in/bus-tickets/gangarampur-to-kolkata
# Found 11 buses on page https://www.redbus.in/bus-tickets/gangarampur-to-kolkata
# Added bus: NBSTC-BLG-KOL-R1-18:30
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Sonar Tori
# Added bus: New Dolphin Travels
# Added bus: New Dolphin Travels
# Added bus: Mohanta Travels
# Added bus: Jio Dolphin Travels
# Added bus: Swarnali Paribahan
# Added bus: Shree Krishna Travels
# Added bus: Padmanabha Paribahan
# Added bus: Renuka Travels
# https://www.redbus.in/bus-tickets/siliguri-to-ranaghat
# Found 7 buses on page https://www.redbus.in/bus-tickets/siliguri-to-ranaghat
# Added bus: NBSTC-SLG-KOL-R1-18:30
# Added bus: Lokenath Bus Service
# Added bus: Lokenath Bus Service
# Added bus: RAYAN
# Added bus: Modern Travels
# Added bus: Lokenath Bus Service
# Added bus: Aradhana Bus Service
# https://www.redbus.in/bus-tickets/siliguri-to-krishnanagar
# Found 14 buses on page https://www.redbus.in/bus-tickets/siliguri-to-krishnanagar
# Added bus: NBSTC-SLG-KOL-R1-18:30
# Added bus: Aradhana Travels
# Added bus: Rubi Paribahan
# Added bus: Lokenath Bus Service
# Added bus: EASY RIDE
# Added bus: RAYAN
# Added bus: Lokenath Bus Service
# Added bus: Modern Travels
# Added bus: Express Line
# Added bus: Kanchanjangha (Saha Travels)
# Added bus: Lokenath Bus Service
# Added bus: Mahaprabhu Travels
# Added bus: Poulami Paribahan
# Added bus: Aradhana Bus Service
# https://www.redbus.in/bus-tickets/falakata-to-kolkata
# Error loading page https://www.redbus.in/bus-tickets/falakata-to-kolkata: Message:
#
# https://www.redbus.in/bus-tickets/kolkata-to-farakka
# Found 11 buses on page https://www.redbus.in/bus-tickets/kolkata-to-farakka
# Added bus: NBSTC-KOL-RAI-R1-20:30
# Added bus: Express Line
# Added bus: Shyamoli Paribahan Pvt Ltd
# Added bus: Lokenath Bus Service
# Added bus: Rubi Paribahan
# Added bus: Rubi Paribahan
# Added bus: Wasim Travels
# Added bus: Wasim Travels
# Added bus: Aradhana Bus Service
# Added bus: Lokenath Bus Service
# Added bus: Swarnali Paribahan
# https://www.redbus.in/bus-tickets/siliguri-to-raiganj
# Found 3 buses on page https://www.redbus.in/bus-tickets/siliguri-to-raiganj
# Added bus: Shree Krishna Travels
# Added bus: Aradhana Bus Service
# Added bus: EASY RIDE
# https://www.redbus.in/bus-tickets/kolkata-to-dhupguri-west-bengal
# Found 1 buses on page https://www.redbus.in/bus-tickets/kolkata-to-dhupguri-west-bengal
# Added bus: NBSTC-KOL-COB-R1-17:00
# https://www.redbus.in/bus-tickets/falakata-to-malda
# Found 1 buses on page https://www.redbus.in/bus-tickets/falakata-to-malda
# Added bus: NBSTC-COB-BHP-R1-19:00
# https://www.redbus.in/bus-tickets/kolkata-to-gazole
# Found 7 buses on page https://www.redbus.in/bus-tickets/kolkata-to-gazole
# Added bus: NBSTC-KOL-RAI-R1-20:30
# Added bus: Express Line
# Added bus: Rubi Paribahan
# Added bus: New Dolphin Travels
# Added bus: Aradhana Bus Service
# Added bus: Lokenath Bus Service
# Added bus: Swarnali Paribahan
# https://www.redbus.in/bus-tickets/berhampore-to-falakata
# Found 1 buses on page https://www.redbus.in/bus-tickets/berhampore-to-falakata
# Added bus: NBSTC-BHP-COB-R1-18:30
# https://www.redbus.in/bus-tickets/balurghat-to-siliguri
# Found 7 buses on page https://www.redbus.in/bus-tickets/balurghat-to-siliguri
# Added bus: New Dolphin Travels
# Added bus: Mohanta Travels
# Added bus: Padmanabha Travels
# Added bus: Shree Krishna Travels
# Added bus: Sankar Travels
# Added bus: Shree Krishna Travels
# Added bus: Gopal Travels
# https://www.redbus.in/bus-tickets/siliguri-to-barasat-west-bengal
# Found 2 buses on page https://www.redbus.in/bus-tickets/siliguri-to-barasat-west-bengal
# Added bus: NBSTC-SLG-KOL-R1-18:30
# Added bus: Aradhana Bus Service
# https://www.redbus.in/bus-tickets/kolkata-to-maynaguri-west-bengal
# Found 1 buses on page https://www.redbus.in/bus-tickets/kolkata-to-maynaguri-west-bengal
# Added bus: NBSTC-KOL-COB-R1-17:00
# https://www.redbus.in/bus-tickets/kolkata-to-itahar-west-bengal
# Found 3 buses on page https://www.redbus.in/bus-tickets/kolkata-to-itahar-west-bengal
# Added bus: NBSTC-KOL-RAI-R1-20:30
# Added bus: Aradhana Bus Service
# Added bus: Lokenath Bus Service
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-krishnanagar
# Found 1 buses on page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-krishnanagar
# Added bus: Mahaprabhu Travels
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-omarpur-west-bengal
# Found 1 buses on page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-omarpur-west-bengal
# Added bus: NBSTC-COB-BHP-R1-19:00
# https://www.redbus.in/bus-tickets/berhampore-to-jalpaiguri
# Found 1 buses on page https://www.redbus.in/bus-tickets/berhampore-to-jalpaiguri
# Added bus: NBSTC-BHP-COB-R1-18:30
# https://www.redbus.in/bus-tickets/malda-to-siliguri
# Found 4 buses on page https://www.redbus.in/bus-tickets/malda-to-siliguri
# Added bus: New Das Paribahan
# Added bus: Aradhana Travels
# Added bus: Aradhana Travels
# Error scraping bus data: UNIQUE constraint failed: Bus_Routes.route_name, Bus_Routes.bus_name, Bus_Routes.departure_time
# https://www.redbus.in/bus-tickets/raiganj-to-ranaghat
# Found 3 buses on page https://www.redbus.in/bus-tickets/raiganj-to-ranaghat
# Added bus: NBSTC-RAI-KOL-R1-19:30
# Added bus: Lokenath Bus Service
# Added bus: Aradhana Bus Service
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-farakka
# Found 1 buses on page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-farakka
# Added bus: NBSTC-COB-BHP-R1-19:00
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-siliguri
# Found 1 buses on page https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-siliguri
# Added bus: NBSTC-COB-FKT-SLG-06-15:30
# https://www.redbus.in/bus-tickets/guwahati-to-shillong
# Found 1 buses on page https://www.redbus.in/bus-tickets/guwahati-to-shillong
# Added bus: Capital Tours India Pvt. Ltd.
# https://www.redbus.in/bus-tickets/shillong-to-tura-meghalaya
# Found 1 buses on page https://www.redbus.in/bus-tickets/shillong-to-tura-meghalaya
# Added bus: NETWORK TRAVELS
# https://www.redbus.in/bus-tickets/shillong-to-guwahati
# Found 1 buses on page https://www.redbus.in/bus-tickets/shillong-to-guwahati
# Added bus: RAYAN TRAVELS
# https://www.redbus.in/bus-tickets/tura-meghalaya-to-shillong
# Error loading page https://www.redbus.in/bus-tickets/tura-meghalaya-to-shillong: Message:
#
# https://www.redbus.in/bus-tickets/shillong-to-silchar
# Found 3 buses on page https://www.redbus.in/bus-tickets/shillong-to-silchar
# Added bus: Meghalaya Transport Corporation(MTC) - 163308
# Added bus: Capital Tours India Pvt. Ltd.
# Added bus: SEEMA TRAVELS
# https://www.redbus.in/bus-tickets/silchar-to-shillong
# Found 1 buses on page https://www.redbus.in/bus-tickets/silchar-to-shillong
# Added bus: Jagannath Travels and Tours Pvt. Ltd.
# https://www.redbus.in/bus-tickets/shillong-to-karimganj
# Found 2 buses on page https://www.redbus.in/bus-tickets/shillong-to-karimganj
# Added bus: RAYAN TRAVELS
# Added bus: JAYSIKA
# https://www.redbus.in/bus-tickets/shillong-to-williamnagar-meghalaya
# Error loading page https://www.redbus.in/bus-tickets/shillong-to-williamnagar-meghalaya: Message:
#
# https://www.redbus.in/bus-tickets/karimganj-to-shillong
# Found 2 buses on page https://www.redbus.in/bus-tickets/karimganj-to-shillong
# Added bus: Meghalaya Transport Corporation(MTC) - 163361
# Added bus: Meghalaya Transport Corporation(MTC) - 170076
# https://www.redbus.in/bus-tickets/williamnagar-meghalaya-to-shillong
# Error loading page https://www.redbus.in/bus-tickets/williamnagar-meghalaya-to-shillong: Message:
#
# https://www.redbus.in/bus-tickets/shillong-to-hailakandi
# Found 1 buses on page https://www.redbus.in/bus-tickets/shillong-to-hailakandi
# Added bus: Meghalaya Transport Corporation(MTC) - 163369
# https://www.redbus.in/bus-tickets/shillong-to-ramkrishnanagar
# Found 1 buses on page https://www.redbus.in/bus-tickets/shillong-to-ramkrishnanagar
# Added bus: Meghalaya Transport Corporation(MTC) - 163369
# https://www.redbus.in/bus-tickets/hailakandi-to-shillong
# Found 1 buses on page https://www.redbus.in/bus-tickets/hailakandi-to-shillong
# Added bus: Meghalaya Transport Corporation(MTC) - 163368
# https://www.redbus.in/bus-tickets/ramkrishnanagar-to-shillong
# Found 1 buses on page https://www.redbus.in/bus-tickets/ramkrishnanagar-to-shillong
# Added bus: Meghalaya Transport Corporation(MTC) - 163368
# https://www.redbus.in/bus-tickets/shillong-to-phulbari
# Error loading page https://www.redbus.in/bus-tickets/shillong-to-phulbari: Message:
#
# {'route_name': 'ramkrishnanagar-to-shillong', 'route_link': 'https://www.redbus.in/bus-tickets/ramkrishnanagar-to-shillong', 'bus_name': 'Meghalaya Transport Corporation(MTC) - 163368', 'bus_type': 'Tata Non A/C Seater Executive Luxury (2+2)', 'departure_time': '17:00', 'duration': '11h 00m', 'arrival_time': '04:00', 'rating': '3.8', 'price': 425.0, 'availability': '2 Seats available'}

# %%
# %%writefile applicationsam.py
import streamlit as st
import pandas as pd
import sqlite3
from sqlalchemy import create_engine



css='''
<style>
    [data-testid="stExpander"] div:has(>.streamlit-expanderContent) {
        overflow: scroll;
        height: 400px;
    }
</style>
'''

st.markdown(css, unsafe_allow_html=True)

db_name = 'redbus_data.db'

def make_clickable(val):
    return f'<a target="_blank" href="{val}">{val}</a>'


def load_data():
    conn = sqlite3.connect(db_name)
    query = "SELECT * FROM Bus_Routes"
    df = pd.read_sql(query, conn)
    conn.close()
    return df


df = load_data()


df['price'] = pd.to_numeric(df['price'], errors='coerce')


st.title('Bus Route Finder')


bus_types = st.multiselect('Select Bus Type', options=df['bus_type'].unique())
routes = st.multiselect('Select Route', options=df['route_name'].unique())
price_range = st.slider('Select Price Range', min_value=int(df['price'].min()), max_value=int(df['price'].max()), value=(int(df['price'].min()), int(df['price'].max())))
star_rating = st.slider('Select Star Rating', min_value=float(df['rating'].min()), max_value=float(df['rating'].max()), value=(float(df['rating'].min()), float(df['rating'].max())))
availability = st.selectbox('Select Availability', options=['All', 'Available'])


filtered_df = df.copy()
if bus_types:
    filtered_df = filtered_df[filtered_df['bus_type'].isin(bus_types)]
if routes:
    filtered_df = filtered_df[filtered_df['route_name'].isin(routes)]
filtered_df = filtered_df[(filtered_df['price'] >= price_range[0]) & (filtered_df['price'] <= price_range[1])]
filtered_df = filtered_df[(filtered_df['rating'] >= star_rating[0]) & (filtered_df['rating'] <= star_rating[1])]
if availability == 'Available':
    filtered_df = filtered_df[filtered_df['availability'] != 'Sold Out']


filtered_df['route_link'] = filtered_df['route_link'].apply(make_clickable)

st.markdown(filtered_df[['bus_name', 'route_link', 'price', 'availability']].to_html(escape=False), unsafe_allow_html=True)


#st.dataframe(filtered_df[['bus_name','route_link','price','availability']])


if st.checkbox('Show Raw Data'):
    st.write(df)
# Out:
# Overwriting applicationsam.py

# %%
# !streamlit run applicationsam.py
# Out:
# ^C

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import sqlite3


conn = sqlite3.connect('redbus_data.db')
cursor = conn.cursor()

cursor.execute("select count(*) from bus_routes")

for i in cursor:
    print(i)
# Out:
# (5635,)
